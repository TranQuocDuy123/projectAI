# %% [markdown]
# <a href="https://colab.research.google.com/github/TranQuocDuy123/projectAI/blob/main/projectAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam,SGD
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Tạo ra class ImageDataGenerator để chỉnh sửa ảnh 
train_datagen=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
training_data=train_datagen.flow_from_directory('/content/drive/MyDrive/projectAI/huyet_dao/train',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 594 images belonging to 7 classes.

# %%
validation_data=train_datagen.flow_from_directory('/content/drive/MyDrive/projectAI/huyet_dao/test',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 168 images belonging to 7 classes.

# %%
training_data.class_indices
# Out:
# {'AnDuong': 0,
#  'BachHoi': 1,
#  'NghinhHuong': 2,
#  'SuatCoc': 3,
#  'ThaiDuong': 4,
#  'ThienTru': 5,
#  'ToanTruc': 6}

# %%
model=Sequential()
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(256,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 256 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(256,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(512,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 512 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(512,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(512,activation='relu',kernel_initializer='he_uniform'))
model.add(Dense(512,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(7,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 256)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 18, 18, 512)       1180160
#
#  conv2d_7 (Conv2D)           (None, 18, 18, 512)       2359808
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 512)               21234176
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_2 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 26,185,799
# Trainable params: 26,185,799
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt=SGD(lr=0.01,momentum=0.9)
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
history=model.fit(training_data,epochs=500,batch_size=100,verbose=1, validation_data=validation_data, callbacks=[EarlyStopping(monitor='val_loss', patience=30)])
# Out:
# Epoch 1/500
# 19/19 [==============================] - 164s 8s/step - loss: 2.9712 - accuracy: 0.1936 - val_loss: 1.8623 - val_accuracy: 0.2619
# Epoch 2/500
# 19/19 [==============================] - 6s 337ms/step - loss: 1.8451 - accuracy: 0.2643 - val_loss: 1.8588 - val_accuracy: 0.2321
# Epoch 3/500
# 19/19 [==============================] - 6s 334ms/step - loss: 1.8453 - accuracy: 0.2660 - val_loss: 1.8523 - val_accuracy: 0.2619
# Epoch 4/500
# 19/19 [==============================] - 6s 336ms/step - loss: 1.8340 - accuracy: 0.2677 - val_loss: 1.8520 - val_accuracy: 0.2619
# Epoch 5/500
# 19/19 [==============================] - 6s 331ms/step - loss: 1.8484 - accuracy: 0.2744 - val_loss: 1.8555 - val_accuracy: 0.2619
# Epoch 6/500
# 19/19 [==============================] - 6s 340ms/step - loss: 1.8330 - accuracy: 0.2761 - val_loss: 1.8468 - val_accuracy: 0.2738
# Epoch 7/500
# 19/19 [==============================] - 7s 341ms/step - loss: 1.8221 - accuracy: 0.2862 - val_loss: 1.8274 - val_accuracy: 0.2619
# Epoch 8/500
# 19/19 [==============================] - 7s 346ms/step - loss: 1.8067 - accuracy: 0.3030 - val_loss: 1.8583 - val_accuracy: 0.2500
# Epoch 9/500
# 19/19 [==============================] - 7s 343ms/step - loss: 1.8243 - accuracy: 0.3114 - val_loss: 1.8470 - val_accuracy: 0.2798
# Epoch 10/500
# 19/19 [==============================] - 7s 340ms/step - loss: 1.8141 - accuracy: 0.2879 - val_loss: 1.8384 - val_accuracy: 0.2619
# Epoch 11/500
# 19/19 [==============================] - 7s 341ms/step - loss: 1.8316 - accuracy: 0.2896 - val_loss: 1.8610 - val_accuracy: 0.2619
# Epoch 12/500
# 19/19 [==============================] - 6s 348ms/step - loss: 1.8169 - accuracy: 0.2811 - val_loss: 1.8115 - val_accuracy: 0.2857
# Epoch 13/500
# 19/19 [==============================] - 6s 336ms/step - loss: 1.8295 - accuracy: 0.2727 - val_loss: 1.8338 - val_accuracy: 0.2798
# Epoch 14/500
# 19/19 [==============================] - 6s 339ms/step - loss: 1.8129 - accuracy: 0.2912 - val_loss: 1.8418 - val_accuracy: 0.2500
# Epoch 15/500
# 19/19 [==============================] - 7s 340ms/step - loss: 1.8149 - accuracy: 0.2896 - val_loss: 1.8115 - val_accuracy: 0.3333
# Epoch 16/500
# 19/19 [==============================] - 6s 340ms/step - loss: 1.7780 - accuracy: 0.3350 - val_loss: 1.7724 - val_accuracy: 0.3274
# Epoch 17/500
# 19/19 [==============================] - 7s 346ms/step - loss: 1.7737 - accuracy: 0.3199 - val_loss: 1.7808 - val_accuracy: 0.3214
# Epoch 18/500
# 19/19 [==============================] - 7s 345ms/step - loss: 1.7722 - accuracy: 0.3114 - val_loss: 1.7872 - val_accuracy: 0.3214
# Epoch 19/500
# 19/19 [==============================] - 7s 345ms/step - loss: 1.7310 - accuracy: 0.3165 - val_loss: 1.8287 - val_accuracy: 0.2857
# Epoch 20/500
# 19/19 [==============================] - 7s 345ms/step - loss: 1.7035 - accuracy: 0.3401 - val_loss: 1.6814 - val_accuracy: 0.3512
# Epoch 21/500
# 19/19 [==============================] - 7s 344ms/step - loss: 1.6752 - accuracy: 0.3535 - val_loss: 1.6691 - val_accuracy: 0.3333
# Epoch 22/500
# 19/19 [==============================] - 7s 343ms/step - loss: 1.6349 - accuracy: 0.3653 - val_loss: 1.6771 - val_accuracy: 0.3452
# Epoch 23/500
# 19/19 [==============================] - 6s 339ms/step - loss: 1.6091 - accuracy: 0.3721 - val_loss: 1.6304 - val_accuracy: 0.4107
# Epoch 24/500
# 19/19 [==============================] - 7s 341ms/step - loss: 1.5852 - accuracy: 0.3805 - val_loss: 1.6178 - val_accuracy: 0.3750
# Epoch 25/500
# 19/19 [==============================] - 7s 343ms/step - loss: 1.5772 - accuracy: 0.4007 - val_loss: 1.6609 - val_accuracy: 0.3571
# Epoch 26/500
# 19/19 [==============================] - 7s 345ms/step - loss: 1.7124 - accuracy: 0.3350 - val_loss: 1.7153 - val_accuracy: 0.3274
# Epoch 27/500
# 19/19 [==============================] - 8s 402ms/step - loss: 1.6504 - accuracy: 0.3569 - val_loss: 1.7409 - val_accuracy: 0.3214
# Epoch 28/500
# 19/19 [==============================] - 7s 350ms/step - loss: 1.6141 - accuracy: 0.3603 - val_loss: 1.6399 - val_accuracy: 0.3452
# Epoch 29/500
# 19/19 [==============================] - 7s 341ms/step - loss: 1.5447 - accuracy: 0.3990 - val_loss: 1.6272 - val_accuracy: 0.3929
# Epoch 30/500
# 19/19 [==============================] - 7s 347ms/step - loss: 1.5337 - accuracy: 0.4259 - val_loss: 1.5955 - val_accuracy: 0.4226
# Epoch 31/500
# 19/19 [==============================] - 7s 343ms/step - loss: 1.5263 - accuracy: 0.3973 - val_loss: 1.5540 - val_accuracy: 0.3750
# Epoch 32/500
# 19/19 [==============================] - 6s 338ms/step - loss: 1.4789 - accuracy: 0.4175 - val_loss: 1.5591 - val_accuracy: 0.4464
# Epoch 33/500
# 19/19 [==============================] - 7s 340ms/step - loss: 1.5133 - accuracy: 0.4125 - val_loss: 1.6422 - val_accuracy: 0.3512
# Epoch 34/500
# 19/19 [==============================] - 7s 343ms/step - loss: 1.5013 - accuracy: 0.4411 - val_loss: 1.4903 - val_accuracy: 0.4643
# Epoch 35/500
# 19/19 [==============================] - 7s 341ms/step - loss: 1.4325 - accuracy: 0.4697 - val_loss: 1.4438 - val_accuracy: 0.4821
# Epoch 36/500
# 19/19 [==============================] - 6s 340ms/step - loss: 1.3880 - accuracy: 0.4747 - val_loss: 1.5524 - val_accuracy: 0.4464
# Epoch 37/500
# 19/19 [==============================] - 6s 338ms/step - loss: 1.3971 - accuracy: 0.4630 - val_loss: 1.4259 - val_accuracy: 0.4107
# Epoch 38/500
# 19/19 [==============================] - 7s 339ms/step - loss: 1.3140 - accuracy: 0.4832 - val_loss: 1.3602 - val_accuracy: 0.4881
# Epoch 39/500
# 19/19 [==============================] - 7s 344ms/step - loss: 1.3201 - accuracy: 0.5185 - val_loss: 1.4775 - val_accuracy: 0.4583
# Epoch 40/500
# 19/19 [==============================] - 6s 339ms/step - loss: 1.2846 - accuracy: 0.5370 - val_loss: 1.3562 - val_accuracy: 0.5655
# Epoch 41/500
# 19/19 [==============================] - 7s 341ms/step - loss: 1.2511 - accuracy: 0.5438 - val_loss: 1.4218 - val_accuracy: 0.4881
# Epoch 42/500
# 19/19 [==============================] - 6s 340ms/step - loss: 1.2422 - accuracy: 0.5623 - val_loss: 1.2364 - val_accuracy: 0.5357
# Epoch 43/500
# 19/19 [==============================] - 7s 340ms/step - loss: 1.1531 - accuracy: 0.5657 - val_loss: 1.2293 - val_accuracy: 0.5774
# Epoch 44/500
# 19/19 [==============================] - 7s 341ms/step - loss: 1.0774 - accuracy: 0.5976 - val_loss: 1.2101 - val_accuracy: 0.5952
# Epoch 45/500
# 19/19 [==============================] - 6s 337ms/step - loss: 1.1022 - accuracy: 0.5842 - val_loss: 1.1611 - val_accuracy: 0.5774
# Epoch 46/500
# 19/19 [==============================] - 6s 336ms/step - loss: 1.0795 - accuracy: 0.5875 - val_loss: 1.3327 - val_accuracy: 0.5357
# Epoch 47/500
# 19/19 [==============================] - 6s 335ms/step - loss: 1.1063 - accuracy: 0.5825 - val_loss: 1.3612 - val_accuracy: 0.4940
# Epoch 48/500
# 19/19 [==============================] - 6s 337ms/step - loss: 1.0615 - accuracy: 0.5943 - val_loss: 1.1360 - val_accuracy: 0.6369
# Epoch 49/500
# 19/19 [==============================] - 6s 340ms/step - loss: 1.0819 - accuracy: 0.6212 - val_loss: 1.1447 - val_accuracy: 0.5893
# Epoch 50/500
# 19/19 [==============================] - 6s 338ms/step - loss: 0.9407 - accuracy: 0.6616 - val_loss: 1.1102 - val_accuracy: 0.6071
# Epoch 51/500
# 19/19 [==============================] - 6s 336ms/step - loss: 0.8771 - accuracy: 0.6751 - val_loss: 1.1819 - val_accuracy: 0.6429
# Epoch 52/500
# 19/19 [==============================] - 6s 339ms/step - loss: 0.8788 - accuracy: 0.6852 - val_loss: 0.9626 - val_accuracy: 0.7024
# Epoch 53/500
# 19/19 [==============================] - 7s 342ms/step - loss: 0.8268 - accuracy: 0.6970 - val_loss: 0.9532 - val_accuracy: 0.6726
# Epoch 54/500
# 19/19 [==============================] - 7s 344ms/step - loss: 0.8205 - accuracy: 0.7037 - val_loss: 0.8738 - val_accuracy: 0.6845
# Epoch 55/500
# 19/19 [==============================] - 7s 347ms/step - loss: 0.7563 - accuracy: 0.7323 - val_loss: 0.8960 - val_accuracy: 0.7202
# Epoch 56/500
# 19/19 [==============================] - 7s 344ms/step - loss: 0.8206 - accuracy: 0.7138 - val_loss: 1.0004 - val_accuracy: 0.7143
# Epoch 57/500
# 19/19 [==============================] - 6s 336ms/step - loss: 0.6746 - accuracy: 0.7508 - val_loss: 0.8092 - val_accuracy: 0.7560
# Epoch 58/500
# 19/19 [==============================] - 7s 340ms/step - loss: 0.6605 - accuracy: 0.7694 - val_loss: 0.9000 - val_accuracy: 0.7500
# Epoch 59/500
# 19/19 [==============================] - 6s 334ms/step - loss: 0.6379 - accuracy: 0.7660 - val_loss: 0.7415 - val_accuracy: 0.7798
# Epoch 60/500
# 19/19 [==============================] - 6s 334ms/step - loss: 0.6586 - accuracy: 0.7694 - val_loss: 0.7712 - val_accuracy: 0.7500
# Epoch 61/500
# 19/19 [==============================] - 6s 336ms/step - loss: 0.5794 - accuracy: 0.7828 - val_loss: 0.7755 - val_accuracy: 0.7798
# Epoch 62/500
# 19/19 [==============================] - 6s 337ms/step - loss: 0.5726 - accuracy: 0.7980 - val_loss: 0.7396 - val_accuracy: 0.7560
# Epoch 63/500
# 19/19 [==============================] - 7s 342ms/step - loss: 0.5353 - accuracy: 0.8114 - val_loss: 0.9100 - val_accuracy: 0.7560
# Epoch 64/500
# 19/19 [==============================] - 6s 338ms/step - loss: 0.5857 - accuracy: 0.8165 - val_loss: 0.7991 - val_accuracy: 0.7857
# Epoch 65/500
# 19/19 [==============================] - 6s 337ms/step - loss: 0.5164 - accuracy: 0.8215 - val_loss: 0.8246 - val_accuracy: 0.7440
# Epoch 66/500
# 19/19 [==============================] - 6s 334ms/step - loss: 0.5748 - accuracy: 0.8081 - val_loss: 1.1012 - val_accuracy: 0.7440
# Epoch 67/500
# 19/19 [==============================] - 6s 337ms/step - loss: 0.9989 - accuracy: 0.6481 - val_loss: 1.0680 - val_accuracy: 0.6131
# Epoch 68/500
# 19/19 [==============================] - 6s 338ms/step - loss: 0.7506 - accuracy: 0.7306 - val_loss: 0.8110 - val_accuracy: 0.7262
# Epoch 69/500
# 19/19 [==============================] - 6s 338ms/step - loss: 0.5877 - accuracy: 0.7912 - val_loss: 0.8068 - val_accuracy: 0.7798
# Epoch 70/500
# 19/19 [==============================] - 6s 339ms/step - loss: 0.5893 - accuracy: 0.7946 - val_loss: 0.8800 - val_accuracy: 0.7202
# Epoch 71/500
# 19/19 [==============================] - 6s 335ms/step - loss: 0.4982 - accuracy: 0.7997 - val_loss: 0.8747 - val_accuracy: 0.7440
# Epoch 72/500
# 19/19 [==============================] - 8s 406ms/step - loss: 0.4911 - accuracy: 0.8350 - val_loss: 0.7754 - val_accuracy: 0.7917
# Epoch 73/500
# 19/19 [==============================] - 6s 336ms/step - loss: 0.4417 - accuracy: 0.8535 - val_loss: 0.6996 - val_accuracy: 0.8036
# Epoch 74/500
# 19/19 [==============================] - 6s 336ms/step - loss: 0.4065 - accuracy: 0.8519 - val_loss: 0.7958 - val_accuracy: 0.8631
# Epoch 75/500
# 19/19 [==============================] - 6s 335ms/step - loss: 0.3984 - accuracy: 0.8704 - val_loss: 0.8960 - val_accuracy: 0.8095
# Epoch 76/500
# 19/19 [==============================] - 6s 336ms/step - loss: 0.4583 - accuracy: 0.8367 - val_loss: 0.6175 - val_accuracy: 0.8274
# Epoch 77/500
# 19/19 [==============================] - 6s 340ms/step - loss: 0.3706 - accuracy: 0.8653 - val_loss: 0.6420 - val_accuracy: 0.8274
# Epoch 78/500
# 19/19 [==============================] - 6s 334ms/step - loss: 0.4057 - accuracy: 0.8569 - val_loss: 0.7464 - val_accuracy: 0.8333
# Epoch 79/500
# 19/19 [==============================] - 6s 337ms/step - loss: 0.3948 - accuracy: 0.8636 - val_loss: 0.7249 - val_accuracy: 0.8155
# Epoch 80/500
# 19/19 [==============================] - 6s 337ms/step - loss: 0.4207 - accuracy: 0.8468 - val_loss: 0.6733 - val_accuracy: 0.8036
# Epoch 81/500
# 19/19 [==============================] - 6s 340ms/step - loss: 0.3460 - accuracy: 0.8822 - val_loss: 0.8808 - val_accuracy: 0.8274
# Epoch 82/500
# 19/19 [==============================] - 7s 344ms/step - loss: 0.3498 - accuracy: 0.8872 - val_loss: 0.6649 - val_accuracy: 0.8095
# Epoch 83/500
# 19/19 [==============================] - 6s 336ms/step - loss: 0.3440 - accuracy: 0.8923 - val_loss: 0.6474 - val_accuracy: 0.8452
# Epoch 84/500
# 19/19 [==============================] - 6s 334ms/step - loss: 0.3194 - accuracy: 0.8838 - val_loss: 0.7484 - val_accuracy: 0.8452
# Epoch 85/500
# 19/19 [==============================] - 6s 335ms/step - loss: 0.2826 - accuracy: 0.8990 - val_loss: 0.8378 - val_accuracy: 0.8214
# Epoch 86/500
# 19/19 [==============================] - 6s 337ms/step - loss: 0.2816 - accuracy: 0.9040 - val_loss: 0.7111 - val_accuracy: 0.8333
# Epoch 87/500
# 19/19 [==============================] - 6s 340ms/step - loss: 0.2857 - accuracy: 0.9040 - val_loss: 0.5906 - val_accuracy: 0.8571
# Epoch 88/500
# 19/19 [==============================] - 6s 336ms/step - loss: 0.3271 - accuracy: 0.8990 - val_loss: 1.0178 - val_accuracy: 0.7976
# Epoch 89/500
# 19/19 [==============================] - 6s 336ms/step - loss: 0.5159 - accuracy: 0.8232 - val_loss: 0.8178 - val_accuracy: 0.8155
# Epoch 90/500
# 19/19 [==============================] - 6s 337ms/step - loss: 0.3562 - accuracy: 0.8737 - val_loss: 0.6509 - val_accuracy: 0.8512
# Epoch 91/500
# 19/19 [==============================] - 6s 340ms/step - loss: 0.3149 - accuracy: 0.8855 - val_loss: 0.6693 - val_accuracy: 0.8452
# Epoch 92/500
# 19/19 [==============================] - 6s 334ms/step - loss: 0.3655 - accuracy: 0.8569 - val_loss: 0.5844 - val_accuracy: 0.8571
# Epoch 93/500
# 19/19 [==============================] - 6s 335ms/step - loss: 0.3027 - accuracy: 0.8906 - val_loss: 0.5507 - val_accuracy: 0.8690
# Epoch 94/500
# 19/19 [==============================] - 6s 335ms/step - loss: 0.2761 - accuracy: 0.8939 - val_loss: 0.5405 - val_accuracy: 0.8452
# Epoch 95/500
# 19/19 [==============================] - 6s 337ms/step - loss: 0.2800 - accuracy: 0.9091 - val_loss: 0.6370 - val_accuracy: 0.8333
# Epoch 96/500
# 19/19 [==============================] - 6s 337ms/step - loss: 0.3013 - accuracy: 0.8838 - val_loss: 0.7103 - val_accuracy: 0.8155
# Epoch 97/500
# 19/19 [==============================] - 6s 333ms/step - loss: 0.3120 - accuracy: 0.8838 - val_loss: 0.6928 - val_accuracy: 0.8214
# Epoch 98/500
# 19/19 [==============================] - 6s 343ms/step - loss: 0.2915 - accuracy: 0.8939 - val_loss: 0.6406 - val_accuracy: 0.8631
# Epoch 99/500
# 19/19 [==============================] - 6s 339ms/step - loss: 0.2761 - accuracy: 0.9108 - val_loss: 0.6143 - val_accuracy: 0.8750
# Epoch 100/500
# 19/19 [==============================] - 6s 338ms/step - loss: 0.2118 - accuracy: 0.9360 - val_loss: 0.6567 - val_accuracy: 0.8690
# Epoch 101/500
# 19/19 [==============================] - 6s 338ms/step - loss: 0.2094 - accuracy: 0.9259 - val_loss: 0.6654 - val_accuracy: 0.7857
# Epoch 102/500
# 19/19 [==============================] - 6s 338ms/step - loss: 0.2957 - accuracy: 0.9007 - val_loss: 0.7556 - val_accuracy: 0.8750
# Epoch 103/500
# 19/19 [==============================] - 7s 344ms/step - loss: 0.2186 - accuracy: 0.9158 - val_loss: 0.7331 - val_accuracy: 0.8750
# Epoch 104/500
# 19/19 [==============================] - 7s 342ms/step - loss: 0.2892 - accuracy: 0.9007 - val_loss: 0.7632 - val_accuracy: 0.8155
# Epoch 105/500
# 19/19 [==============================] - 6s 337ms/step - loss: 0.1960 - accuracy: 0.9377 - val_loss: 0.7678 - val_accuracy: 0.8571
# Epoch 106/500
# 19/19 [==============================] - 7s 341ms/step - loss: 0.1985 - accuracy: 0.9293 - val_loss: 0.5653 - val_accuracy: 0.8988
# Epoch 107/500
# 19/19 [==============================] - 6s 332ms/step - loss: 0.2010 - accuracy: 0.9276 - val_loss: 0.6678 - val_accuracy: 0.8810
# Epoch 108/500
# 19/19 [==============================] - 6s 345ms/step - loss: 0.1587 - accuracy: 0.9478 - val_loss: 0.7886 - val_accuracy: 0.8452
# Epoch 109/500
# 19/19 [==============================] - 6s 339ms/step - loss: 0.2106 - accuracy: 0.9276 - val_loss: 0.4828 - val_accuracy: 0.8512
# Epoch 110/500
# 19/19 [==============================] - 7s 344ms/step - loss: 0.1810 - accuracy: 0.9276 - val_loss: 0.9988 - val_accuracy: 0.8631
# Epoch 111/500
# 19/19 [==============================] - 6s 339ms/step - loss: 0.1545 - accuracy: 0.9327 - val_loss: 0.5534 - val_accuracy: 0.8929
# Epoch 112/500
# 19/19 [==============================] - 6s 338ms/step - loss: 0.1352 - accuracy: 0.9411 - val_loss: 0.9491 - val_accuracy: 0.8631
# Epoch 113/500
# 19/19 [==============================] - 7s 345ms/step - loss: 0.1571 - accuracy: 0.9394 - val_loss: 0.6571 - val_accuracy: 0.8512
# Epoch 114/500
# 19/19 [==============================] - 6s 339ms/step - loss: 0.1892 - accuracy: 0.9276 - val_loss: 0.7488 - val_accuracy: 0.8631
# Epoch 115/500
# 19/19 [==============================] - 6s 340ms/step - loss: 0.1697 - accuracy: 0.9478 - val_loss: 0.5269 - val_accuracy: 0.8988
# Epoch 116/500
# 19/19 [==============================] - 6s 338ms/step - loss: 0.2285 - accuracy: 0.9259 - val_loss: 0.4919 - val_accuracy: 0.8988
# Epoch 117/500
# 19/19 [==============================] - 7s 387ms/step - loss: 0.2005 - accuracy: 0.9293 - val_loss: 0.8281 - val_accuracy: 0.8810
# Epoch 118/500
# 19/19 [==============================] - 7s 356ms/step - loss: 0.2207 - accuracy: 0.9259 - val_loss: 0.7428 - val_accuracy: 0.8512
# Epoch 119/500
# 19/19 [==============================] - 6s 339ms/step - loss: 0.1979 - accuracy: 0.9327 - val_loss: 0.6510 - val_accuracy: 0.8750
# Epoch 120/500
# 19/19 [==============================] - 7s 340ms/step - loss: 0.1552 - accuracy: 0.9377 - val_loss: 0.5932 - val_accuracy: 0.9048
# Epoch 121/500
# 19/19 [==============================] - 6s 339ms/step - loss: 0.1402 - accuracy: 0.9478 - val_loss: 0.7070 - val_accuracy: 0.8810
# Epoch 122/500
# 19/19 [==============================] - 7s 340ms/step - loss: 0.2746 - accuracy: 0.9209 - val_loss: 0.8681 - val_accuracy: 0.8631
# Epoch 123/500
# 19/19 [==============================] - 6s 339ms/step - loss: 0.1618 - accuracy: 0.9343 - val_loss: 0.6125 - val_accuracy: 0.8750
# Epoch 124/500
# 19/19 [==============================] - 7s 342ms/step - loss: 0.1541 - accuracy: 0.9461 - val_loss: 0.6224 - val_accuracy: 0.8869
# Epoch 125/500
# 19/19 [==============================] - 6s 338ms/step - loss: 0.1146 - accuracy: 0.9562 - val_loss: 0.5221 - val_accuracy: 0.9167
# Epoch 126/500
# 19/19 [==============================] - 7s 342ms/step - loss: 0.1077 - accuracy: 0.9663 - val_loss: 0.7487 - val_accuracy: 0.8929
# Epoch 127/500
# 19/19 [==============================] - 7s 344ms/step - loss: 0.1337 - accuracy: 0.9529 - val_loss: 0.7080 - val_accuracy: 0.8929
# Epoch 128/500
# 19/19 [==============================] - 7s 342ms/step - loss: 0.1355 - accuracy: 0.9545 - val_loss: 0.7875 - val_accuracy: 0.8810
# Epoch 129/500
# 19/19 [==============================] - 7s 347ms/step - loss: 0.1107 - accuracy: 0.9613 - val_loss: 0.6418 - val_accuracy: 0.8810
# Epoch 130/500
# 19/19 [==============================] - 7s 342ms/step - loss: 0.1026 - accuracy: 0.9579 - val_loss: 0.9899 - val_accuracy: 0.8929
# Epoch 131/500
# 19/19 [==============================] - 6s 337ms/step - loss: 0.1053 - accuracy: 0.9579 - val_loss: 0.6605 - val_accuracy: 0.9107
# Epoch 132/500
# 19/19 [==============================] - 7s 341ms/step - loss: 0.1220 - accuracy: 0.9613 - val_loss: 0.6778 - val_accuracy: 0.8929
# Epoch 133/500
# 19/19 [==============================] - 6s 340ms/step - loss: 0.1044 - accuracy: 0.9579 - val_loss: 0.7073 - val_accuracy: 0.8869
# Epoch 134/500
# 19/19 [==============================] - 7s 342ms/step - loss: 0.1048 - accuracy: 0.9613 - val_loss: 0.6904 - val_accuracy: 0.9107
# Epoch 135/500
# 19/19 [==============================] - 7s 341ms/step - loss: 0.0606 - accuracy: 0.9764 - val_loss: 0.8731 - val_accuracy: 0.8810
# Epoch 136/500
# 19/19 [==============================] - 7s 344ms/step - loss: 0.1216 - accuracy: 0.9444 - val_loss: 0.6238 - val_accuracy: 0.8929
# Epoch 137/500
# 19/19 [==============================] - 6s 338ms/step - loss: 0.0992 - accuracy: 0.9680 - val_loss: 0.7475 - val_accuracy: 0.8988
# Epoch 138/500
# 19/19 [==============================] - 7s 344ms/step - loss: 0.0855 - accuracy: 0.9663 - val_loss: 0.8131 - val_accuracy: 0.8750
# Epoch 139/500
# 19/19 [==============================] - 7s 342ms/step - loss: 0.1701 - accuracy: 0.9562 - val_loss: 0.6366 - val_accuracy: 0.8929

# %%
Score=model.evaluate(validation_data,verbose=0)
print('Test loss',Score[0])
print('Test accuary', Score[1])
# Out:
# Test loss 0.7253366112709045
# Test accuary 0.886904776096344

# %%
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('Model Accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epochs')
  plt.legend(['Train','Validation'])
  plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
model.save("/content/drive/MyDrive/projectAI/Final.h5")

# %%
model_CNN=load_model('/content/drive/MyDrive/projectAI/Final.h5')

# %%
img=load_img('/content/drive/MyDrive/projectAI/huyet_dao/test/AnDuong/5.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='AnDuong'
elif round(result[0][1])==1:
  prediction='BachHoi'
elif round(result[0][2])==1:
  prediction='NghinhHuong'
elif round(result[0][3])==1:
  prediction='SuatCoc'
elif round(result[0][4])==1:
  prediction='ThaiDuong'
elif round(result[0][5])==1:
  prediction='ThienTru'
elif round(result[0][6])==1:
  prediction='ToanTruc'
print(prediction)
# Out:
# AnDuong

# %%
img=load_img('/content/drive/MyDrive/projectAI/huyet_dao/test/BachHoi/1.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='AnDuong'
elif round(result[0][1])==1:
  prediction='BachHoi'
elif round(result[0][2])==1:
  prediction='NghinhHuong'
elif round(result[0][3])==1:
  prediction='SuatCoc'
elif round(result[0][4])==1:
  prediction='ThaiDuong'
elif round(result[0][5])==1:
  prediction='ThienTru'
elif round(result[0][6])==1:
  prediction='ToanTruc'
print(prediction)
# Out:
# BachHoi

# %%
img=load_img('/content/drive/MyDrive/projectAI/huyet_dao/test/NghinhHuong/1.JPG',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='AnDuong'
elif round(result[0][1])==1:
  prediction='BachHoi'
elif round(result[0][2])==1:
  prediction='NghinhHuong'
elif round(result[0][3])==1:
  prediction='SuatCoc'
elif round(result[0][4])==1:
  prediction='ThaiDuong'
elif round(result[0][5])==1:
  prediction='ThienTru'
elif round(result[0][6])==1:
  prediction='ToanTruc'
print(prediction)
# Out:
# NghinhHuong

# %%
img=load_img('/content/drive/MyDrive/projectAI/huyet_dao/test/SuatCoc/1.JPG',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='AnDuong'
elif round(result[0][1])==1:
  prediction='BachHoi'
elif round(result[0][2])==1:
  prediction='NghinhHuong'
elif round(result[0][3])==1:
  prediction='SuatCoc'
elif round(result[0][4])==1:
  prediction='ThaiDuong'
elif round(result[0][5])==1:
  prediction='ThienTru'
elif round(result[0][6])==1:
  prediction='ToanTruc'
print(prediction)
# Out:
# SuatCoc

# %%
img=load_img('/content/drive/MyDrive/projectAI/huyet_dao/test/ThaiDuong/1.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='AnDuong'
elif round(result[0][1])==1:
  prediction='BachHoi'
elif round(result[0][2])==1:
  prediction='NghinhHuong'
elif round(result[0][3])==1:
  prediction='SuatCoc'
elif round(result[0][4])==1:
  prediction='ThaiDuong'
elif round(result[0][5])==1:
  prediction='ThienTru'
elif round(result[0][6])==1:
  prediction='ToanTruc'
print(prediction)
# Out:
# ThaiDuong

# %%
img=load_img('/content/drive/MyDrive/projectAI/huyet_dao/test/ThienTru/1.JPG',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='AnDuong'
elif round(result[0][1])==1:
  prediction='BachHoi'
elif round(result[0][2])==1:
  prediction='NghinhHuong'
elif round(result[0][3])==1:
  prediction='SuatCoc'
elif round(result[0][4])==1:
  prediction='ThaiDuong'
elif round(result[0][5])==1:
  prediction='ThienTru'
elif round(result[0][6])==1:
  prediction='ToanTruc'
print(prediction)
# Out:
# ThienTru

# %%
img=load_img('/content/drive/MyDrive/projectAI/huyet_dao/test/ToanTruc/1.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='AnDuong'
elif round(result[0][1])==1:
  prediction='BachHoi'
elif round(result[0][2])==1:
  prediction='NghinhHuong'
elif round(result[0][3])==1:
  prediction='SuatCoc'
elif round(result[0][4])==1:
  prediction='ThaiDuong'
elif round(result[0][5])==1:
  prediction='ThienTru'
elif round(result[0][6])==1:
  prediction='ToanTruc'
print(prediction)
# Out:
# ToanTruc

# %%
# function to convert the JavaScript object into an OpenCV image
def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# function to convert OpenCV Rectangle bounding box image into base64 byte string to be overlayed on video stream
def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')
  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes

# %%
from IPython.display import display, Javascript, Image
# JavaScript to properly create our live video stream using our webcam as input

def video_stream():
  js = Javascript('''
    var video;
    var div = null;
    var stream;
    var captureCanvas;
    var imgElement;
    var labelElement;
    
    var pendingResolve = null;
    var shutdown = false;
    
    function removeDom() {
       stream.getVideoTracks()[0].stop();
       video.remove();
       div.remove();
       video = null;
       div = null;
       stream = null;
       imgElement = null;
       captureCanvas = null;
       labelElement = null;
    }
    
    function onAnimationFrame() {
      if (!shutdown) {
        window.requestAnimationFrame(onAnimationFrame);
      }
      if (pendingResolve) {
        var result = "";
        if (!shutdown) {
          captureCanvas.getContext('2d').drawImage(video, 0, 0, 640, 480);
          result = captureCanvas.toDataURL('image/jpeg', 0.8)
        }
        var lp = pendingResolve;
        pendingResolve = null;
        lp(result);
      }
    }
    
    async function createDom() {
      if (div !== null) {
        return stream;
      }

      div = document.createElement('div');
      div.style.border = '2px solid black';
      div.style.padding = '3px';
      div.style.width = '100%';
      div.style.maxWidth = '600px';
      document.body.appendChild(div);
      
      const modelOut = document.createElement('div');
      modelOut.innerHTML = "<span>Status:</span>";
      labelElement = document.createElement('span');
      labelElement.innerText = 'No data';
      labelElement.style.fontWeight = 'bold';
      modelOut.appendChild(labelElement);
      div.appendChild(modelOut);
           
      video = document.createElement('video');
      video.style.display = 'block';
      video.width = div.clientWidth - 6;
      video.setAttribute('playsinline', '');
      video.onclick = () => { shutdown = true; };
      stream = await navigator.mediaDevices.getUserMedia(
          {video: { facingMode: "environment"}});
      div.appendChild(video);

      imgElement = document.createElement('img');
      imgElement.style.position = 'absolute';
      imgElement.style.zIndex = 1;
      imgElement.onclick = () => { shutdown = true; };
      div.appendChild(imgElement);
      
      const instruction = document.createElement('div');
      instruction.innerHTML = 
          '<span style="color: red; font-weight: bold;">' +
          'Bấm vào video để dừng</span>';
      div.appendChild(instruction);
      instruction.onclick = () => { shutdown = true; };
      
      video.srcObject = stream;
      await video.play();

      captureCanvas = document.createElement('canvas');
      captureCanvas.width = 640; //video.videoWidth;
      captureCanvas.height = 480; //video.videoHeight;
      window.requestAnimationFrame(onAnimationFrame);
      
      return stream;
    }
    async function stream_frame(label, imgData) {
      if (shutdown) {
        removeDom();
        shutdown = false;
        return '';
      }

      var preCreate = Date.now();
      stream = await createDom();
      
      var preShow = Date.now();
      if (label != "") {
        labelElement.innerHTML = label;
      }
            
      if (imgData != "") {
        var videoRect = video.getClientRects()[0];
        imgElement.style.top = videoRect.top + "px";
        imgElement.style.left = videoRect.left + "px";
        imgElement.style.width = videoRect.width + "px";
        imgElement.style.height = videoRect.height + "px";
        imgElement.src = imgData;
      }
      
      var preCapture = Date.now();
      var result = await new Promise(function(resolve, reject) {
        pendingResolve = resolve;
      });
      shutdown = false;
      
      return {'create': preShow - preCreate, 
              'show': preCapture - preShow, 
              'capture': Date.now() - preCapture,
              'img': result};
    }
    ''')

  display(js)
  
def video_frame(label, bbox):
  data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
  return data

# %%
# %cd /content
from google.colab.output import eval_js
from google.colab.patches import cv2_imshow
from base64 import b64decode, b64encode
import numpy as np
import PIL
import io
import cv2
from keras.models import  load_model

# start streaming video from webcam
video_stream()
# label for video
label_html = 'Đang lấy hình ảnh...'
# initialze bounding box to empty
bbox = ''
count = 0 

# Load model Nhận diện tiền
model_file_path = "/content/drive/MyDrive/projectAI/Final.h5"
vggmodel = load_model(model_file_path)

classes = ['AnDuong','BachHoi','NghinhHuong','SuatCoc','ThaiDuong','ThienTru','ToanTruc']
while True:
    # Đọc ảnh trả về từ JS
    js_reply = video_frame(label_html, bbox)
    if not js_reply:
        break

    # convert JS response to OpenCV Image
    frame = js_to_image(js_reply["img"])

    # Resize để đưa vào model
    frame_p = cv2.resize(frame, dsize=(150,150))
    tensor = np.expand_dims(frame_p, axis=0)

    # Feed vào mạng
    pred = vggmodel.predict(tensor)
    class_id = np.argmax(pred)
    class_name = classes[class_id]

    # Vẽ lên một ảnh để tẹo nữa overlay

    # create transparent overlay for bounding box
    bbox_array = np.zeros([480,640,4], dtype=np.uint8)
   
    bbox_array = cv2.putText(bbox_array, "{}".format(class_name),
                        (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                        (0, 255,0), 2)

    bbox_array[:,:,3] = (bbox_array.max(axis = 2) > 0 ).astype(int) * 255
    # convert overlay of bbox into bytes
    bbox_bytes = bbox_to_bytes(bbox_array)
    # update bbox so next frame gets new overlay
    bbox = bbox_bytes
# Out:
# /content
